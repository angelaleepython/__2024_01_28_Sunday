# %%
import pandas as pd

df1 = pd.read_csv('各鄉鎮市區人口密度.csv')
df2 = df1.rename(columns={"statistic_yyy":"統計年",'site_id':'區域別','people_total':'年底人口數','area':'土地面積','population_density':'人口密度'})
df3 = df2.drop(0)
df4 = df3.reindex(index=range(1,371))
df4
# Out:
#      統計年     區域別   年底人口數     土地面積   人口密度
# 1    106  新北市板橋區  551480  23.1373  23835
# 2    106  新北市三重區  387484   16.317  23747
# 3    106  新北市中和區  413590   20.144  20532
# 4    106  新北市永和區  222585   5.7138  38956
# 5    106  新北市新莊區  416524  19.7383  21102
# ..   ...     ...     ...      ...    ...
# 366  106  連江縣北竿鄉    2360      9.9    238
# 367  106  連江縣莒光鄉    1624      4.7    346
# 368  106  連江縣東引鄉    1352      3.8    356
# 369  106    東沙群島      …      2.38     …
# 370  106    南沙群島      …    0.5045     …
#
# [370 rows x 5 columns]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 1 to 370
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   統計年     370 non-null    object
#  1   區域別     370 non-null    object
#  2   年底人口數   370 non-null    object
#  3   土地面積    370 non-null    object
#  4   人口密度    370 non-null    object
# dtypes: object(5)
# memory usage: 14.6+ KB

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 1 to 370
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   統計年     370 non-null    object
#  1   區域別     370 non-null    object
#  2   年底人口數   370 non-null    object
#  3   土地面積    370 non-null    object
#  4   人口密度    370 non-null    object
# dtypes: object(5)
# memory usage: 14.6+ KB

# %%
df4['年底人口數']
# Out:
# 1      551480
# 2      387484
# 3      413590
# 4      222585
# 5      416524
#         ...
# 366      2360
# 367      1624
# 368      1352
# 369        …
# 370        …
# Name: 年底人口數, Length: 370, dtype: object

# %%
df4[['年底人口數','土地面積']]
# Out:
#       年底人口數     土地面積
# 1    551480  23.1373
# 2    387484   16.317
# 3    413590   20.144
# 4    222585   5.7138
# 5    416524  19.7383
# ..      ...      ...
# 366    2360      9.9
# 367    1624      4.7
# 368    1352      3.8
# 369      …      2.38
# 370      …    0.5045
#
# [370 rows x 2 columns]

# %%
df4[['年底人口數','土地面積']]
# Out:
#       年底人口數     土地面積
# 1    551480  23.1373
# 2    387484   16.317
# 3    413590   20.144
# 4    222585   5.7138
# 5    416524  19.7383
# ..      ...      ...
# 366    2360      9.9
# 367    1624      4.7
# 368    1352      3.8
# 369      …      2.38
# 370      …    0.5045
#
# [370 rows x 2 columns]

# %%
#replace(),astype()

serial1 = df4['年底人口數'].replace(to_replace='… ',value='0')
df4['年底人口數'] = serial1.astype(int)
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 1 to 370
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   統計年     370 non-null    object
#  1   區域別     370 non-null    object
#  2   年底人口數   370 non-null    int64
#  3   土地面積    370 non-null    object
#  4   人口密度    370 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 14.6+ KB

# %%
serial2 = df4['人口密度'].replace(to_replace='… ',value='0')
df4['人口密度'] = serial2.astype(int)
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 1 to 370
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   統計年     370 non-null    object
#  1   區域別     370 non-null    object
#  2   年底人口數   370 non-null    int64
#  3   土地面積    370 non-null    object
#  4   人口密度    370 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 14.6+ KB

# %%
df4['人口密度']=df4['土地面積'].astype(float)
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 1 to 370
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   統計年     370 non-null    object
#  1   區域別     370 non-null    object
#  2   年底人口數   370 non-null    int64
#  3   土地面積    370 non-null    object
#  4   人口密度    370 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 14.6+ KB

# %%
df4
# Out:
#      統計年     區域別   年底人口數     土地面積   人口密度
# 1    106  新北市板橋區  551480  23.1373  23835
# 2    106  新北市三重區  387484   16.317  23747
# 3    106  新北市中和區  413590   20.144  20532
# 4    106  新北市永和區  222585   5.7138  38956
# 5    106  新北市新莊區  416524  19.7383  21102
# ..   ...     ...     ...      ...    ...
# 366  106  連江縣北竿鄉    2360      9.9    238
# 367  106  連江縣莒光鄉    1624      4.7    346
# 368  106  連江縣東引鄉    1352      3.8    356
# 369  106    東沙群島       0     2.38      0
# 370  106    南沙群島       0   0.5045      0
#
# [370 rows x 5 columns]

# %%
#sort_valus()

populations_df = df4.sort_values(by='年底人口數',ascending=False)
populations_df
# Out:
#      統計年     區域別   年底人口數     土地面積   人口密度
# 1    106  新北市板橋區  551480  23.1373  23835
# 42   106  桃園市桃園區  440840  34.8046  12666
# 5    106  新北市新莊區  416524  19.7383  21102
# 3    106  新北市中和區  413590   20.144  20532
# 43   106  桃園市中壢區  405216    76.52   5296
# ..   ...     ...     ...      ...    ...
# 367  106  連江縣莒光鄉    1624      4.7    346
# 368  106  連江縣東引鄉    1352      3.8    356
# 364  106  金門縣烏坵鄉     685      1.2    571
# 369  106    東沙群島       0     2.38      0
# 370  106    南沙群島       0   0.5045      0
#
# [370 rows x 5 columns]

# %%
#人口數最多的前5個
populations_df.iloc[:5]

#人口數最少的5個
populations_df.iloc[-5:]
# Out:
#      統計年     區域別  年底人口數    土地面積  人口密度
# 367  106  連江縣莒光鄉   1624     4.7   346
# 368  106  連江縣東引鄉   1352     3.8   356
# 364  106  金門縣烏坵鄉    685     1.2   571
# 369  106    東沙群島      0    2.38     0
# 370  106    南沙群島      0  0.5045     0

# %%
df4['人口密度']=df4['土地面積'].astype(float)
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 1 to 370
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   統計年     370 non-null    object
#  1   區域別     370 non-null    object
#  2   年底人口數   370 non-null    int64
#  3   土地面積    370 non-null    object
#  4   人口密度    370 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 14.6+ KB

# %%
populations_df[populations_df['土地面積'] > 100]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 populations_df[populations_df['土地面積'] > 100]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:6110, in Series._cmp_method(self, other, op)
#    6107 lvalues = self._values
#    6108 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# ...
