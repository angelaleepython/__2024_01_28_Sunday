# %%
import numpy as np
import pandas as pd

scores = np.random.randint(50,101,size=(50,5))
df1 = pd.DataFrame(scores,
             columns=['國文', '英文', '數學', '地理', '歷史'],
             index=range(1,51))
df1.index.name='學號'
df1.columns.name="科目"
df1
# Out:
# 科目   國文   英文  數學  地理   歷史
# 學號
# 1    98   51  52  82   55
# 2    95   61  71  93   80
# 3    66   70  84  72   58
# 4    89   76  81  78   96
# 5    64   72  68  64   98
# 6   100   56  91  73   87
# 7    97   72  50  84   62
# 8    83   56  53  72   96
# 9    74  100  56  57   65
# 10   72   81  76  72   56
# 11   99   76  50  77   75
# 12   79   91  69  71   66
# 13   72   60  60  78   97
# 14   88   70  84  97   52
# 15   77   62  81  78   55
# 16   90   91  96  73   82
# 17   53   71  91  75   82
# 18   85   63  92  61   58
# 19   60   69  55  70   82
# 20   80   69  90  96   89
# 21   92   76  61  96   61
# 22   67   59  54  60   98
# 23   66   82  72  83   88
# 24   70   71  65  82   96
# 25   81   61  60  88   54
# 26   98   81  96  66   86
# 27   74   97  71  79   51
# 28   98   80  85  69   54
# 29   67   81  85  66   75
# 30   94   66  70  95   74
# 31   85   85  87  64   94
# 32   64   85  98  51   84
# 33   99   70  58  69   66
# 34   84   64  58  53   98
# 35   75   97  66  85   62
# 36   66   76  68  81  100
# 37   65   83  72  58   84
# 38   89   82  91  60   79
# 39   51   78  85  82   69
# 40   54   71  98  55   78
# 41   71   92  97  61   56
# 42   91   50  88  63   99
# 43   96   65  97  70   60
# 44   51   59  57  62   58
# 45   85   56  92  91   56
# 46   73   80  94  52   51
# 47   94   75  51  79   65
# 48   65   70  54  87   52
# 49   95   89  85  86   70
# 50   91   76  63  64   83

# %%
from pandas import Series
def fun1(value:Series) -> Series:
    return pd.Series([value.max(),value.min(),value.median()],index=["最高分","最低分",'中間分'])

df2 = df1.apply(fun1)
df2
# Out:
# 科目      國文     英文    數學    地理     歷史
# 最高分  100.0  100.0  98.0  97.0  100.0
# 最低分   51.0   50.0  50.0  51.0   51.0
# 中間分   80.5   72.0  72.0  72.5   74.5

# %%
#轉換成numpy
df1.values[:,0]
# Out:
# array([ 98,  95,  66,  89,  64, 100,  97,  83,  74,  72,  99,  79,  72,
#         88,  77,  90,  53,  85,  60,  80,  92,  67,  66,  70,  81,  98,
#         74,  98,  67,  94,  85,  64,  99,  84,  75,  66,  65,  89,  51,
#         54,  71,  91,  96,  51,  85,  73,  94,  65,  95,  91])

# %%
#轉成csv
df2.to_csv('3年1班統計資料.csv')

# %%
#轉成excel
df2.to_excel('3年1班統計資料.xlsx')
