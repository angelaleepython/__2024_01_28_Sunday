# %%
file=open("names.txt")
type(file)
# Out:
# _io.TextIOWrapper

# %%
file=open("names.txt")
#處理file實體
file.close()

# %%
file=open("names.txt")
#處理file實體
file.close()
file.closed
# Out:
# True

# %%
file=open("names.txt")
#處理file實體
file.close()
if file.closed:
    print("file物件被關閉")
else:
    print("file物件沒有被關閉")
# Out:
# file物件被關閉

# %%
with open("names.txt",encoding="utf-8") as file:
    display(file.readline())
#跳出程市區塊  即自動close()


if file.closed:
    print("file物件被關閉")
else:
    print("file物件沒有被關閉")
# Out:
# '陳怡伶\n'
# file物件被關閉

# %%
with open("names.txt",encoding="utf-8") as file:
    for i in file:
        display(i)
#跳出程市區塊  即自動close()


if file.closed:
    print("file物件被關閉")
else:
    print("file物件沒有被關閉")

# %%
with open('names.txt',encoding='utf-8') as file:
    names: str = file.read()

names
# Out:
# '陳怡伶\n馮芳如\n蒙淑惠\n張軒宸\n陳向愛\n賴心怡\n王怡珊\n林詠斌\n陳淑娟\n崔孝憲\n林希啟\n楊韋廷\n陳文賢\n王士銘\n賴昌韻\n黃名明\n吳麗卿\n游治旺\n蔡嘉音\n黃靜怡\n黃淑芬\n龔姵君\n景歡燦\n李政成\n楊綺芬\n昌嘉洋\n李慈啟\n游倫城\n林淑安\n蔡士賢\n林世城\n林佳蓉\n柯宜臻\n傅佳琳\n林瑞喬\n林佳慧\n鍾俞禎\n劉慧君\n劉林中\n林怡偉\n余丞苓\n黃佩玲\n林建宏\n方雅慧\n林柏洋\n郭舜昇\n艾巧夫\n童建霖\n蔡至剛\n黃心航\n張凡成\n郭淑枝\n黃必琪\n楊健麟\n林建勳\n鄭琇亞\n王雅琴\n李美洋\n楊少亮\n王泓泰\n黃江旭\n王梅劭\n林佳光\n盧必妍\n林思賢\n鄧哲榮\n陳家年\n張俊傑\n洪阿惠\n陳彥治\n盧冠發\n程玫靖\n潘俊賢\n呂傑宣\n鄭孟芳\n彭茹靖\n王孝純\n吳昕婷\n朱惠儀\n盧文啟\n謝佳穎\n鄭憲定\n馮淑芬\n聶心怡\n黃志福\n馬彥文\n郭淑真\n吳欣書\n鄭佳玲\n黃健發\n胡姿婷\n林義皓\n胡芳瑜\n楊易政\n王德城\n劉依婷\n吳俐芷\n黃詩妃\n柯韋成\n鄧亭聿\n王雅慧\n陳凱翔\n藍哲嘉\n趙偉銘\n張韋成\n林向鈺\n周琬婷\n尚偉倫\n賴佳雯\n陳姵彬\n林群清\n趙家豪\n李政白\n林俊翔\n李進慧\n楊韻如\n藍姿婷\n劉嘉泰\n王柏聖\n孫宜珊\n戴萱能\n高士凱\n楊又源\n劉昀天\n王怡君\n余月修\n劉萬季\n陳信宏\n陳孝邦\n朱彥志\n陳奇瑄\n鄧淑娟\n陳逸凡\n張牧聿\n唐雪豪\n林康亮\n黃旻林\n蕭淑華\n劉雯芬\n陳美惠\n孫火清\n溫法堯\n錢欣潔\n陳倩潔\n李雅怡\n白美珍\n葉
珊\n張慧君\n翁羽威\n羅幸娥\n陳俊憲\n洪奎夫\n翁均安\n吳明妮\n高智超\n王人仰\n劉旭士\n蘇凡菁\n謝哲維\n彭偉妃\n劉耿琦\n黃柏宇\n李佳彥\n唐翊修\n陳建香\n葉軍仰\n吳志宣\n林珈發\n黃翔杰\n郭坤花\n吳淑惠\n簡美君\n許芳如\n謝水儒\n陳怡容\n蔡欣汝\n王良斌\n周家銘\n張凱妮\n鄭淑珍\n陳嘉淑\n魏秋萍\n簡佳樺\n劉佳佩\n李彥伸\n陳筱涵\n蔡明平\n王展人\n方筠紹\n陳志偉\n錢佩豪\n陳冠霞\n潘英迪\n陳冠竹\n李淑芳\n謝南慧\n趙家豪\n龐皓芳\n張彥博'
# file物件被關閉

# %%
with open('names.txt',encoding='utf-8') as file:

    names:str=file.read()
name_list:list[str]=names.split(sep="\n")
name_list
# Out:
# ['陳怡伶',
#  '馮芳如',
#  '蒙淑惠',
#  '張軒宸',
#  '陳向愛',
#  '賴心怡',
#  '王怡珊',
#  '林詠斌',
#  '陳淑娟',
#  '崔孝憲',
#  '林希啟',
#  '楊韋廷',
#  '陳文賢',
#  '王士銘',
#  '賴昌韻',
#  '黃名明',
#  '吳麗卿',
#  '游治旺',
#  '蔡嘉音',
#  '黃靜怡',
#  '黃淑芬',
#  '龔姵君',
#  '景歡燦',
#  '李政成',
#  '楊綺芬',
#  '昌嘉洋',
#  '李慈啟',
#  '游倫城',
#  '林淑安',
#  '蔡士賢',
#  '林世城',
#  '林佳蓉',
#  '柯宜臻',
#  '傅佳琳',
#  '林瑞喬',
#  '林佳慧',
#  '鍾俞禎',
#  '劉慧君',
#  '劉林中',
#  '林怡偉',
#  '余丞苓',
#  '黃佩玲',
#  '林建宏',
#  '方雅慧',
#  '林柏洋',
#  '郭舜昇',
#  '艾巧夫',
#  '童建霖',
#  '蔡至剛',
#  '黃心航',
#  '張凡成',
#  '郭淑枝',
#  '黃必琪',
#  '楊健麟',
#  '林建勳',
#  '鄭琇亞',
#  '王雅琴',
#  '李美洋',
#  '楊少亮',
#  '王泓泰',
#  '黃江旭',
#  '王梅劭',
#  '林佳光',
#  '盧必妍',
#  '林思賢',
#  '鄧哲榮',
#  '陳家年',
#  '張俊傑',
#  '洪阿惠',
#  '陳彥治',
#  '盧冠發',
#  '程玫靖',
#  '潘俊賢',
#  '呂傑宣',
#  '鄭孟芳',
#  '彭茹靖',
#  '王孝純',
#  '吳昕婷',
#  '朱惠儀',
#  '盧文啟',
#  '謝佳穎',
#  '鄭憲定',
#  '馮淑芬',
#  '聶心怡',
#  '黃志福',
#  '馬彥文',
#  '郭淑真',
#  '吳欣書',
#  '鄭佳玲',
#  '黃健發',
#  '胡姿婷',
#  '林義皓',
#  '胡芳瑜',
#  '楊易政',
#  '王德城',
#  '劉依婷',
#  '吳俐芷',
#  '黃詩妃',
#  '柯韋成',
#  '鄧亭聿',
#  '王雅慧',
#  '陳凱翔',
#  '藍哲嘉',
#  '趙偉銘',
#  '張韋成',
#  '林向鈺',
#  '周琬婷',
#  '尚偉倫',
#  '賴佳雯',
#  '陳姵彬',
#  '林群清',
#  '趙家豪',
#  '李政白',
#  '林俊翔',
#  '李進慧',
#  '楊韻如',
#  '藍姿婷',
#  '劉嘉泰',
#  '王柏聖',
#  '孫宜珊',
#  '戴萱能',
#  '高士凱',
#  '楊又源',
#  '劉昀天',
#  '王怡君',
#  '余月修',
#  '劉萬季',
#  '陳信宏',
#  '陳孝邦',
#  '朱彥志',
#  '陳奇瑄',
#  '鄧淑娟',
#  '陳逸凡',
#  '張牧聿',
#  '唐雪豪',
#  '林康亮',
#  '黃旻林',
#  '蕭淑華',
#  '劉雯芬',
#  '陳美惠',
#  '孫火清',
#  '溫法堯',
#  '錢欣潔',
#  '陳倩潔',
#  '李雅怡',
#  '白美珍',
#  '葉志峰',
#  '黃佩芬',
#  '黃麗美',
#  '黃奎紹',
#  '邱亭君',
#  '詹忠光',
#  '戚亨',
#  '賴又琦',
#  '林佳人',
#  '黃善迪',
#  '賴苑禾',
#  '溫重意',
#  '周怡啟',
#  '王明昇',
#  '羅佩樺',
#  '陳家維',
#  '張莉雯',
#  '高俊男',
#  '林冠蕙',
#  '王品星',
#  '吳孟穎',
#  '黃雅慧',
#  '馮耀中',
#  '元延辛',
#  '王坤安',
#  '陳慧君',
#  '張伊映',
#  '林士凱',
#  '蘇婷婷',
#  '陳淑萍',
#  '林玉佩',
#  '謝貞妃',
#  '杜儀鳳',
#  '陳倩妮',
#  '胡淑貞',
#  '楊偉翔',
#  '姜琬婷',
#  '張雅芬',
#  '葉祖雄',
#  '沈心利',
#  '彭虹屏',
#  '余宗儒',
#  '李立偉',
#  '臧怡君',
#  '吳振瑋',
#  '陳建豪',
#  '蕭怡伶',
#  '周芷蓁',
#  '黃偉剛',
#  '黃婷婷',
#  '郎慧萍',
#  '林昱芳',
#  '趙宛真',
#  '白世宏',
#  '杜明延',
#  '許淑婷',
#  '林珍旺',
#  '蔡孟泉',
#  '吳晴洋',
#  '游一鈺',
#  '朱士弘',
#  '黃政甫',
#  '游淑惠',
#  '張婕妤',
#  '陳逸華',
#  '張天亨',
#  '張嘉韋',
#  '王志謙',
#  '黎惠雯',
#  '高信宏',
#  '梁柏宇',
#  '林志喜',
#  '金宜芳',
#  '簡國瑋',
#  '林清英',
#  '黃彥孝',
#  '鄭奇翰',
#  '李慶亮',
#  '李蓉瑞',
#  '張明惟',
#  '游詩亞',
#  '黃嘉琪',
#  '張家秀',
#  '吳柏誠',
#  '陳得映',
#  '郭致恬',
#  '林麗萍',
#  '陳樂紫',
#  '翁鈺婷',
#  '蔡世馨',
#  '楊建安',
#  '李湘婷',
#  '鞠冠宇',
#  '林志成',
#  '陳信念',
#  '林益妏',
#  '蔡偉成',
#  '王惠皓',
#  '王筱婷',
#  '楊火帆',
#  '陳怡珊',
#  '張慧君',
#  '翁羽威',
#  '羅幸娥',
#  '陳俊憲',
#  '洪奎夫',
#  '翁均安',
#  '吳明妮',
#  '高智超',
#  '王人仰',
#  '劉旭士',
#  '蘇凡菁',
#  '謝哲維',
#  '彭偉妃',
#  '劉耿琦',
#  '黃柏宇',
#  '李佳彥',
#  '唐翊修',
#  '陳建香',
#  '葉軍仰',
#  '吳志宣',
#  '林珈發',
#  '黃翔杰',
#  '郭坤花',
#  '吳淑惠',
#  '簡美君',
#  '許芳如',
#  '謝水儒',
#  '陳怡容',
#  '蔡欣汝',
#  '王良斌',
#  '周家銘',
#  '張凱妮',
#  '鄭淑珍',
#  '陳嘉淑',
#  '魏秋萍',
#  '簡佳樺',
#  '劉佳佩',
#  '李彥伸',
#  '陳筱涵',
#  '蔡明平',
#  '王展人',
#  '方筠紹',
#  '陳志偉',
#  '錢佩豪',
#  '陳冠霞',
#  '潘英迪',
#  '陳冠竹',
#  '李淑芳',
#  '謝南慧',
#  '趙家豪',
#  '龐皓芳',
#  '張彥博']

# %%
import random
with open('names.txt',encoding='utf-8') as file:

    names:str=file.read()
name_list:list[str]=names.split(sep="\n")
random.choice(name_list)
# Out:
# '林佳蓉'

# %%
import random
with open('names.txt',encoding='utf-8') as file:

    names:str=file.read()
name_list:list[str]=names.split(sep="\n")
random.choice(name_list)
#choices要加s k=自己決定數量
random.choices(name_list,k=5)
# Out:
# ['王筱婷', '張凡成', '周琬婷', '林俊翔', '趙家豪']

# %%
def get_names(nums=1):
    import random
    with open('names.txt',encoding='utf-8') as file:
        names:str=file.read()
    name_list:list[str]=names.split(sep="\n")  
    return random.choices(name_list,k=nums)

# %%
get_names(nums=6)
# Out:
# ['黃旻林', '王明昇', '高士凱', '陳凱翔', '張伊映', '林柏洋']

# %%
#建立50個學生名字
names: list[str]=get_names(50)
for name in names:
    print(name)
# Out:
# 王明昇
# 李進慧
# 李慶亮
# 吳俐芷
# 張嘉韋
# 王品星
# 葉祖雄
# 蔡明平
# 楊建安
# 朱士弘
# 郭坤花
# 黃柏宇
# 李佳彥
# 簡美君
# 劉旭士
# 謝南慧
# 高信宏
# 張軒宸
# 劉耿琦
# 藍姿婷
# 劉依婷
# 溫法堯
# 林世城
# 林佳蓉
# 鄧淑娟
# 張俊傑
# 李政成
# 李立偉
# 張伊映
# 臧怡君
# 程玫靖
# 王良斌
# 林康亮
# 趙家豪
# 臧怡君
# 李慶亮
# 賴佳雯
# 簡國瑋
# 游倫城
# 林益妏
# 黃名明
# 翁均安
# 高信宏
# 葉志峰
# 張嘉韋
# 張彥博
# 劉耿琦
# 鄧淑娟
# 黃志福
# 蔡嘉音

# %%
#建立50個學生名字
from random import randint
names: list[str]=get_names(50)
students:list[dict]=[]
for name in names:
        student:dict={"姓名":name}
        for subject in ["國文","英文","數學"]:
            student[subject]=randint(50,100)
        students.append(student)

students
# Out:
# [{'姓名': '唐雪豪', '國文': 76, '英文': 89, '數學': 85},
#  {'姓名': '蔡至剛', '國文': 83, '英文': 88, '數學': 75},
#  {'姓名': '孫火清', '國文': 56, '英文': 50, '數學': 54},
#  {'姓名': '張明惟', '國文': 69, '英文': 82, '數學': 82},
#  {'姓名': '劉萬季', '國文': 72, '英文': 61, '數學': 57},
#  {'姓名': '蔡明平', '國文': 90, '英文': 54, '數學': 72},
#  {'姓名': '陳得映', '國文': 86, '英文': 78, '數學': 82},
#  {'姓名': '陳家年', '國文': 88, '英文': 79, '數學': 82},
#  {'姓名': '楊建安', '國文': 59, '英文': 73, '數學': 56},
#  {'姓名': '元延辛', '國文': 99, '英文': 59, '數學': 80},
#  {'姓名': '溫重意', '國文': 78, '英文': 99, '數學': 74},
#  {'姓名': '林佳蓉', '國文': 83, '英文': 60, '數學': 98},
#  {'姓名': '蔡嘉音', '國文': 84, '英文': 91, '數學': 50},
#  {'姓名': '黃心航', '國文': 97, '英文': 58, '數學': 78},
#  {'姓名': '蕭淑華', '國文': 75, '英文': 81, '數學': 85},
#  {'姓名': '林思賢', '國文': 99, '英文': 62, '數學': 100},
#  {'姓名': '劉旭士', '國文': 89, '英文': 80, '數學': 75},
#  {'姓名': '李淑芳', '國文': 60, '英文': 76, '數學': 85},
#  {'姓名': '溫法堯', '國文': 81, '英文': 92, '數學': 93},
#  {'姓名': '王人仰', '國文': 68, '英文': 93, '數學': 66},
#  {'姓名': '陳嘉淑', '國文': 57, '英文': 72, '數學': 77},
#  {'姓名': '楊韻如', '國文': 80, '英文': 79, '數學': 86},
#  {'姓名': '林世城', '國文': 76, '英文': 85, '數學': 51},
#  {'姓名': '彭偉妃', '國文': 90, '英文': 65, '數學': 73},
#  {'姓名': '龐皓芳', '國文': 62, '英文': 76, '數學': 67},
#  {'姓名': '黃志福', '國文': 66, '英文': 52, '數學': 70},
#  {'姓名': '胡姿婷', '國文': 62, '英文': 94, '數學': 56},
#  {'姓名': '錢欣潔', '國文': 88, '英文': 83, '數學': 70},
#  {'姓名': '楊又源', '國文': 96, '英文': 62, '數學': 58},
#  {'姓名': '吳淑惠', '國文': 90, '英文': 94, '數學': 99},
#  {'姓名': '陳嘉淑', '國文': 82, '英文': 56, '數學': 61},
#  {'姓名': '游治旺', '國文': 75, '英文': 58, '數學': 92},
#  {'姓名': '林佳光', '國文': 85, '英文': 99, '數學': 93},
#  {'姓名': '鍾俞禎', '國文': 65, '英文': 79, '數學': 88},
#  {'姓名': '林建宏', '國文': 64, '英文': 73, '數學': 86},
#  {'姓名': '劉嘉泰', '國文': 75, '英文': 65, '數學': 75},
#  {'姓名': '吳孟穎', '國文': 50, '英文': 95, '數學': 98},
#  {'姓名': '林佳慧', '國文': 92, '英文': 58, '數學': 84},
#  {'姓名': '林志成', '國文': 63, '英文': 91, '數學': 64},
#  {'姓名': '郭致恬', '國文': 74, '英文': 83, '數學': 74},
#  {'姓名': '周琬婷', '國文': 79, '英文': 76, '數學': 83},
#  {'姓名': '劉旭士', '國文': 74, '英文': 93, '數學': 65},
#  {'姓名': '鄧淑娟', '國文': 62, '英文': 61, '數學': 93},
#  {'姓名': '白美珍', '國文': 78, '英文': 93, '數學': 64},
#  {'姓名': '張凡成', '國文': 97, '英文': 100, '數學': 97},
#  {'姓名': '黃彥孝', '國文': 79, '英文': 94, '數學': 54},
#  {'姓名': '傅佳琳', '國文': 77, '英文': 74, '數學': 69},
#  {'姓名': '陳嘉淑', '國文': 91, '英文': 57, '數學': 99},
#  {'姓名': '王怡君', '國文': 50, '英文': 73, '數學': 65},
#  {'姓名': '張婕妤', '國文': 59, '英文': 64, '數學': 62}]

# %%
#建立80個學生名字
from random import randint
names: list[str]=get_names(80)
students:list[dict]=[]
for name in names:
        student:dict={"姓名":name}
        for subject in ["國文","英文","數學"]:
            student[subject]=randint(80,100)
        students.append(student)

students
# Out:
# [{'姓名': '簡佳樺', '國文': 83, '英文': 99, '數學': 95},
#  {'姓名': '朱士弘', '國文': 99, '英文': 85, '數學': 85},
#  {'姓名': '賴昌韻', '國文': 92, '英文': 98, '數學': 91},
#  {'姓名': '鄭琇亞', '國文': 81, '英文': 94, '數學': 100},
#  {'姓名': '傅佳琳', '國文': 87, '英文': 96, '數學': 96},
#  {'姓名': '蘇婷婷', '國文': 100, '英文': 85, '數學': 94},
#  {'姓名': '林希啟', '國文': 87, '英文': 90, '數學': 96},
#  {'姓名': '楊綺芬', '國文': 91, '英文': 87, '數學': 86},
#  {'姓名': '張凱妮', '國文': 89, '英文': 88, '數學': 90},
#  {'姓名': '郎慧萍', '國文': 94, '英文': 99, '數學': 96},
#  {'姓名': '黃志福', '國文': 91, '英文': 86, '數學': 92},
#  {'姓名': '楊健麟', '國文': 100, '英文': 81, '數學': 81},
#  {'姓名': '姜琬婷', '國文': 81, '英文': 92, '數學': 80},
#  {'姓名': '黃奎紹', '國文': 85, '英文': 100, '數學': 90},
#  {'姓名': '劉林中', '國文': 81, '英文': 98, '數學': 90},
#  {'姓名': '林建勳', '國文': 99, '英文': 90, '數學': 98},
#  {'姓名': '陳淑萍', '國文': 80, '英文': 91, '數學': 85},
#  {'姓名': '林詠斌', '國文': 82, '英文': 84, '數學': 95},
#  {'姓名': '馮耀中', '國文': 98, '英文': 87, '數學': 94},
#  {'姓名': '劉依婷', '國文': 87, '英文': 89, '數學': 98},
#  {'姓名': '劉耿琦', '國文': 93, '英文': 90, '數學': 89},
#  {'姓名': '陳樂紫', '國文': 84, '英文': 94, '數學': 87},
#  {'姓名': '王筱婷', '國文': 96, '英文': 81, '數學': 92},
#  {'姓名': '游淑惠', '國文': 86, '英文': 98, '數學': 80},
#  {'姓名': '林怡偉', '國文': 81, '英文': 81, '數學': 96},
#  {'姓名': '李彥伸', '國文': 93, '英文': 84, '數學': 89},
#  {'姓名': '魏秋萍', '國文': 100, '英文': 96, '數學': 92},
#  {'姓名': '張俊傑', '國文': 97, '英文': 83, '數學': 96},
#  {'姓名': '張牧聿', '國文': 84, '英文': 97, '數學': 91},
#  {'姓名': '翁均安', '國文': 82, '英文': 97, '數學': 86},
#  {'姓名': '陳樂紫', '國文': 93, '英文': 95, '數學': 80},
#  {'姓名': '詹忠光', '國文': 88, '英文': 99, '數學': 100},
#  {'姓名': '余月修', '國文': 88, '英文': 89, '數學': 87},
#  {'姓名': '陳倩妮', '國文': 90, '英文': 88, '數學': 82},
#  {'姓名': '張韋成', '國文': 93, '英文': 92, '數學': 88},
#  {'姓名': '周琬婷', '國文': 86, '英文': 93, '數學': 91},
#  {'姓名': '黃嘉琪', '國文': 84, '英文': 97, '數學': 90},
#  {'姓名': '陳建香', '國文': 89, '英文': 83, '數學': 80},
#  {'姓名': '陳倩潔', '國文': 91, '英文': 92, '數學': 95},
#  {'姓名': '林佳光', '國文': 83, '英文': 100, '數學': 80},
#  {'姓名': '趙家豪', '國文': 82, '英文': 96, '數學': 97},
#  {'姓名': '李蓉瑞', '國文': 82, '英文': 81, '數學': 85},
#  {'姓名': '方雅慧', '國文': 88, '英文': 91, '數學': 82},
#  {'姓名': '許芳如', '國文': 81, '英文': 95, '數學': 97},
#  {'姓名': '陳冠竹', '國文': 92, '英文': 97, '數學': 97},
#  {'姓名': '賴苑禾', '國文': 97, '英文': 89, '數學': 83},
#  {'姓名': '陳凱翔', '國文': 95, '英文': 86, '數學': 87},
#  {'姓名': '王雅慧', '國文': 91, '英文': 83, '數學': 81},
#  {'姓名': '陳怡伶', '國文': 89, '英文': 92, '數學': 84},
#  {'姓名': '杜儀鳳', '國文': 86, '英文': 90, '數學': 80},
#  {'姓名': '張凡成', '國文': 93, '英文': 99, '數學': 96},
#  {'姓名': '郭坤花', '國文': 97, '英文': 93, '數學': 90},
#  {'姓名': '葉志峰', '國文': 93, '英文': 81, '數學': 83},
#  {'姓名': '趙家豪', '國文': 100, '英文': 80, '數學': 97},
#  {'姓名': '張軒宸', '國文': 83, '英文': 81, '數學': 92},
#  {'姓名': '林佳慧', '國文': 81, '英文': 97, '數學': 82},
#  {'姓名': '陳嘉淑', '國文': 80, '英文': 97, '數學': 90},
#  {'姓名': '王德城', '國文': 99, '英文': 92, '數學': 84},
#  {'姓名': '蘇婷婷', '國文': 86, '英文': 80, '數學': 84},
#  {'姓名': '楊健麟', '國文': 83, '英文': 84, '數學': 82},
#  {'姓名': '蔡明平', '國文': 100, '英文': 84, '數學': 91},
#  {'姓名': '陳信念', '國文': 97, '英文': 80, '數學': 90},
#  {'姓名': '游詩亞', '國文': 81, '英文': 100, '數學': 89},
#  {'姓名': '游詩亞', '國文': 82, '英文': 85, '數學': 92},
#  {'姓名': '羅佩樺', '國文': 87, '英文': 93, '數學': 87},
#  {'姓名': '陳淑萍', '國文': 91, '英文': 81, '數學': 81},
#  {'姓名': '劉慧君', '國文': 91, '英文': 93, '數學': 89},
#  {'姓名': '張軒宸', '國文': 87, '英文': 96, '數學': 98},
#  {'姓名': '童建霖', '國文': 93, '英文': 90, '數學': 92},
#  {'姓名': '高俊男', '國文': 84, '英文': 89, '數學': 82},
#  {'姓名': '陳凱翔', '國文': 81, '英文': 90, '數學': 94},
#  {'姓名': '林義皓', '國文': 87, '英文': 96, '數學': 90},
#  {'姓名': '方雅慧', '國文': 84, '英文': 93, '數學': 81},
#  {'姓名': '張明惟', '國文': 100, '英文': 84, '數學': 84},
#  {'姓名': '周琬婷', '國文': 92, '英文': 80, '數學': 83},
#  {'姓名': '陳姵彬', '國文': 83, '英文': 89, '數學': 93},
#  {'姓名': '簡美君', '國文': 88, '英文': 96, '數學': 95},
#  {'姓名': '張婕妤', '國文': 90, '英文': 89, '數學': 88},
#  {'姓名': '洪奎夫', '國文': 97, '英文': 87, '數學': 91},
#  {'姓名': '林思賢', '國文': 95, '英文': 82, '數學': 92}]

# %%
#建立10個學生名字
from random import randint
names: list[str]=get_names(10)
students:list[dict]=[]
for name in names:
        student:dict={"姓名":name}
        for subject in ["國文","英文","數學"]:
            student[subject]=randint(10,100)
        students.append(student)

students
# Out:
# [{'姓名': '黃柏宇', '國文': 59, '英文': 50, '數學': 72},
#  {'姓名': '楊偉翔', '國文': 40, '英文': 91, '數學': 67},
#  {'姓名': '林康亮', '國文': 68, '英文': 14, '數學': 85},
#  {'姓名': '林珍旺', '國文': 13, '英文': 65, '數學': 60},
#  {'姓名': '林麗萍', '國文': 36, '英文': 82, '數學': 57},
#  {'姓名': '張彥博', '國文': 83, '英文': 38, '數學': 48},
#  {'姓名': '林康亮', '國文': 92, '英文': 85, '數學': 50},
#  {'姓名': '杜明延', '國文': 71, '英文': 96, '數學': 41},
#  {'姓名': '謝南慧', '國文': 53, '英文': 67, '數學': 25},
#  {'姓名': '羅佩樺', '國文': 51, '英文': 90, '數學': 74}]

# %%
#建立一個亂數
#輸入
from random import randint
names: list[str]=get_names(1)
students:list[dict]=[]
for name in names:
        student:dict={"姓名":name}
        for subject in ["身高(公分)","體重(公斤)"]:
            student[subject]=randint(1,100)
        students.append(student)

students

#輸出
#xxx您好:
#您的BMI是:xxx.xxx
#您的體重:過重
# Out:
# [{'姓名': '余丞苓', '身高(公分)': 48, '體重(公斤)': 64}]

# %%
#輸入
from random import randint
names: list[str]=get_names(1)
students:list[dict]=[]
for name in names:
        student:dict={"姓名":name}
        for subject in ["身高(公分)","體重(公斤)"]:
            student[subject]=randint(1,100)
        students.append(student)

students

#輸出

import pyinputplus as pyip

def getSuggestion(bmi:float) -> str:
    print(f'您好，您的BMI值為:{bmi:.2f}')
try:
        height = eval(input('請輸入身高(公分,120-250):'))
        weight = eval(input('請輸入體重(公斤,30-250):'))
        if (height >= 120 and height<=250) and (weight >=30 and weight <=250) :
            bmi = weight/(height/100)**2
            print(getSuggestion(bmi))
        else :
            print(f'您好，您的BMI值為:{bmi:.2f}')
except:
        print('輸入格式有錯誤')


from random import randint
names: list[str]=get_names(1)
students:list[dict]=[]
for name in names:
        student:dict={"姓名":name}
        for subject in ["身高(公分)","體重(公斤)"]:
            student[subject]=randint(1,100)
        students.append(student)

students
# Out:
# 您好，您的BMI值為:22.12
# None
# [{'姓名': '林康亮', '身高(公分)': 60, '體重(公斤)': 37}]
